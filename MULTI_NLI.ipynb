# %%
# importing the libraries 
import torch 
from torch import nn
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import nltk 
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from datasets import load_dataset
import numpy as np
import pandas as pd
import random
from torch import cuda
from pprint import pprint
import re
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# defining the CONSTANTS 
EXCLUDE_STOPWORDS = True
BATCH_SIZE = 8
EPOCHS = 10
LEARNING_RATE = 0.001
EMBEDDING_DIM = 100 
HIDDEN_DIM = 100
GLOVE_PATH = './glove/glove.6B.100d.txt'
DEVICE = 'cuda'
if cuda.is_available():
    DEVICE = 'cuda'
else:
    DEVICE = 'cpu'

# %%
dataset = load_dataset("multi_nli", "default")

# %%
glove = {}
with open(GLOVE_PATH, 'r') as f:
    for line in f:
        line = line.split()
        glove[line[0]] = torch.tensor([float(x) for x in line[1:]])

# create a list of stopwords
stop_words = stopwords.words('english')

glove['<unk>'] = torch.mean(torch.stack(list(glove.values())), dim=0)
glove['<pad>'] = torch.zeros(EMBEDDING_DIM)
glove['<start>'] = torch.rand(EMBEDDING_DIM)
glove['<end>'] = torch.rand(EMBEDDING_DIM)

# %%
# making the word_2_idx and idx_2_word dictionaries and the embedding matrix
word_2_idx = {'<pad>': 0, '<unk>': 1, '<start>': 2, '<end>': 3}
idx_2_word = {0: '<pad>', 1: '<unk>', 2: '<start>', 3: '<end>'}
embedding_matrix = np.zeros((len(glove.values()), EMBEDDING_DIM))
embedding_matrix[0] = glove['<pad>']
embedding_matrix[1] = glove['<unk>']
embedding_matrix[2] = glove['<start>']
embedding_matrix[3] = glove['<end>']

for i, word in enumerate(glove.keys()):
    if word not in word_2_idx:
        word_2_idx[word] = len(word_2_idx)
        idx_2_word[len(idx_2_word)] = word
        embedding_matrix[word_2_idx[word]] = glove[word]

# convert the embedding matrix to a tensor
embedding_matrix = torch.FloatTensor(embedding_matrix)

# %%
random.seed(1)
random.shuffle(dataset['train']['premise'])
random.seed(1)
random.shuffle(dataset['train']['hypothesis'])
random.seed(1)
random.shuffle(dataset['train']['label'])
random.seed(1)
random.shuffle(dataset['validation_matched']['premise'])
random.seed(1)
random.shuffle(dataset['validation_matched']['hypothesis'])
random.seed(1)
random.shuffle(dataset['validation_matched']['label'])

new_dataset = {}
new_dataset['train'] = dataset['train'][:40000]
new_dataset['validation'] = dataset['validation_matched'][:800]
dataset=new_dataset

# %%
raw_datasets = {'train': [], 'validation':[]}
cat_to_name={'entailment': 0, 'neutral': 1, 'contradiction': 2}
#entailment (0), neutral (1), contradiction (2)




def preprocessing(sentence, stop_words_remove):
    sentence = sentence.split(' ')
    if stop_words_remove:
        sentence = [word.lower() for word in sentence if word.lower() not in stop_words]
    else:
        sentence = [word.lower() for word in sentence]
    sentence = ['<start> '] + sentence+ ['<end>']
    sentence = [word_2_idx[word] if word in word_2_idx else word_2_idx['<unk>'] for word in sentence]
    return sentence


# convertng the dataset into list of dicts 
raw_datasets = {'train': [], 'validation':[]}
for i in dataset:
    # for j in (range(len(dataset[i]['genre']))):
    print(len(dataset[i]))

    for j in range(len(dataset[i]['premise'])):

        if dataset[i]['label'][j]== -1:
            continue
       
        tokens = preprocessing(dataset[i]['premise'][j], EXCLUDE_STOPWORDS)
        tokens_hypothesis = preprocessing(dataset[i]['hypothesis'][j], EXCLUDE_STOPWORDS)
        
      
        
        raw_datasets[i].append({'premise': tokens, 'hypothesis': tokens_hypothesis, 'label': dataset[i]['label'][j]})
# Out:
# 10
# 10

# %%
len(raw_datasets['train'])
# Out:
# 40000

# %%
dataset_pretrain = {'train': [], 'validation':[]}
dataset_nli = {'train': [], 'validation':[]}
for i in raw_datasets:
    for j in raw_datasets[i]:
        j['premise'] = torch.LongTensor(j['premise'])
        j['hypothesis'] = torch.LongTensor(j['hypothesis'])
        j['label'] = torch.LongTensor([j['label']])
        dataset_pretrain[i].append({'sentence': j['premise'], 'label': j['premise'][1:]})
        dataset_pretrain[i].append({'sentence': j['hypothesis'], 'label': j['hypothesis'][1:]})
        dataset_nli[i].append({'sentence': (j['premise'] , j['hypothesis']), 'label': j['label']})

# %%
class PretrainDataset(Dataset):
    def __init__(self, data):
        random.shuffle(data)
        self.data = data
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        return self.data[idx]['sentence'], self.data[idx]['label']

class NLIDataset(Dataset):
    def __init__(self, data):
        random.shuffle(data)
        self.data = data
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        return(self.data[idx]['sentence'][0],self.data[idx]['sentence'][1]) , self.data[idx]['label']
        
pretrain_dataset = {'train': PretrainDataset(dataset_pretrain['train']), 'validation': PretrainDataset(dataset_pretrain['validation'])}
nli_dataset = {'train': NLIDataset(dataset_nli['train']), 'validation': NLIDataset(dataset_nli['validation']) }

# %%
def custom_collate(batch):
    sentences = [item[0] for item in batch]
    labels = [item[1] for item in batch]
    
    # Pad sequences to the maximum length in the batch
    padded_sentences = torch.nn.utils.rnn.pad_sequence(sentences, batch_first=True)
    padded_labels = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True)

    return ( padded_sentences,padded_labels)

def custom_collate_nli(batch):
    premises, hypothesis = [item[0][0] for item in batch], [item[0][1] for item in batch]
    labels = [item[1] for item in batch]
  
    # Pad sequences to the maximum length in the batch
    padded_premises = torch.nn.utils.rnn.pad_sequence(premises, batch_first=True)
    padded_hypothesis = torch.nn.utils.rnn.pad_sequence(hypothesis, batch_first=True)
    labels = torch.LongTensor(labels)
    
    return (padded_premises, padded_hypothesis),labels

# %%
pretrain_loaders={}
nli_loaders={}
for i in pretrain_dataset:
    pretrain_loaders[i] = DataLoader(pretrain_dataset[i], batch_size=BATCH_SIZE, collate_fn=custom_collate)
    nli_loaders[i] = DataLoader(nli_dataset[i], batch_size=BATCH_SIZE, collate_fn=custom_collate_nli)

# %%
# defing the model which we are going to pretrain
class ELMo(nn.Module):
    '''this class implements the ELMo model using the BI-LSTM architecture like by stacking two LSTM layers 
    the model is just the head and needs body such as linear layer , mlp , etc based on the task  '''
    def __init__(self, embedding_dim,  hidden_dim1, hidden_dim2 ,batch_size, num_layers=2):
        super(ELMo, self).__init__()
        self.embedding_dim = embedding_dim
        self.num_layers = num_layers
        self.batch_size = batch_size
        self.embedding= nn.Embedding.from_pretrained(embedding_matrix)
        self.embedding.weight.requires_grad = False
        self.lstm1 = nn.LSTM(embedding_dim, hidden_dim1, num_layers=1, batch_first=True, bidirectional=True)
        self.lstm2 = nn.LSTM(hidden_dim1*2, hidden_dim2, num_layers=1, batch_first=True, bidirectional=True)
        self.weight1 = nn.Parameter(torch.randn(1))
        self.weight2 = nn.Parameter(torch.randn(1))
        self.lambda1 = nn.Parameter(torch.randn(1))


    def forward(self, input): 
        # input = [batch_size, seq_len]
        # getting the imput embeddings 
        input_embeddings = self.embedding(input) # [batch_size, seq_len, embedding_dim]
        # passing the embeddings to the first LSTM layer
        output1 , (hidden1, cell1) = self.lstm1(input_embeddings) # [batch_size, seq_len, hidden_dim1]

        # passing the output of the first LSTM layer to the second LSTM layer
        output2 , (hidden2, cell2) = self.lstm2(output1) # [batch_size, seq_len, hidden_dim2]
        # adding the two outputs of the LSTM layers
        
        weighted_output = self.lambda1*((self.weight1 * output1) +( self.weight2 * output2))

        return weighted_output

# %%
class Language_model(nn.Module):
    '''this class implements the language model using the ELMo model as the head and a linear layer as the body'''
    def __init__(self, Elmo_model, vocab_size, embedding_dim):
        super(Language_model, self).__init__()
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.elmo = Elmo_model
        self.linear = nn.Linear(self.embedding_dim, self.vocab_size)
    def forward(self, input):
        # input = [batch_size, seq_len]
        # getting the imput embeddings 
        elmo_output = self.elmo(input) # [batch_size, seq_len, embedding_dim]
        output = self.linear(elmo_output) # [batch_size, seq_len, vocab_size]
        output = F.log_softmax(output, dim=2).permute(0,2,1)[:,:,:-1] # [batch_size, vocab_size, seq_len-1]
        return output

# %%
class NLI(nn.Module): 

    def __init__(self, Elmo_model, embedding_dim, num_classes=3):
        super(NLI, self).__init__()

        self.embedding_dim = embedding_dim
        self.num_classes = num_classes
        self.elmo = Elmo_model
        self.linear1 = nn.Linear(self.embedding_dim*2,50)
        self.relu1= nn.ReLU()
        self.dropout1 = nn.Dropout(0.3)
        self.linear2 = nn.Linear(50,25)
        self.relu2= nn.ReLU()
        self.dropout2 = nn.Dropout(0.3)
        self.linear3 = nn.Linear(25, self.num_classes)
        
    def forward(self, input):
        # getting the imput embeddings
        premise = input[0]
        hypothesis = input[1]
        elmo_output_premise = self.elmo(premise) # [batch_size, seq_len, embedding_dim]
        elmo_output_hypothesis = self.elmo(hypothesis) # [batch_size, seq_len, embedding_dim]
        sentence_embeddings_premise = []
        sentence_embeddings_hypothesis = []
        for i in range(elmo_output_premise.shape[0]):
            sentence_embeddings_premise.append(torch.mean(elmo_output_premise[i], dim=0))
        for i in range(elmo_output_hypothesis.shape[0]):
            sentence_embeddings_hypothesis.append(torch.mean(elmo_output_hypothesis[i], dim=0))
        sentence_embeddings_input = []
        for i in range(elmo_output_hypothesis.shape[0]):
            sentence_embeddings_input.append(torch.cat((sentence_embeddings_premise[i],sentence_embeddings_hypothesis[i]),dim=0))
        sentence_embeddings = torch.stack(sentence_embeddings_input)  # convert list to tensor
        output1 = self.linear1(sentence_embeddings) # [batch_size, num_classes]
        output1= self.relu1(output1)
        output1 = self.dropout1(output1)
        output1 = self.linear2(output1)
        output1= self.relu2(output1)
        output1 = self.dropout2(output1)
        output = self.linear3(output1)
        output = F.log_softmax(output, dim=1) # [batch_size, num_classes]

        return output

# %%
elmo = ELMo(embedding_dim=EMBEDDING_DIM, hidden_dim1=EMBEDDING_DIM//2, hidden_dim2=EMBEDDING_DIM//2, batch_size=BATCH_SIZE)

# %%
model = Language_model(elmo, vocab_size=len(glove), embedding_dim=EMBEDDING_DIM)

# %%
model.to(DEVICE)
criterion = nn.NLLLoss(ignore_index=0 )

# define the optimizer 
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
best_loss = 1000000
best_accuracy = 0
def accuracy(output, label):
    output = torch.max(output, dim=1).indices
    return (output == label).float().mean()
steps = 0

running_loss = 0
model.train()
for epoch in range(3):
    print('epoch: ', epoch)
    if epoch%1  == 0 and epoch != 0:
        for param_group in optimizer.param_groups:
            param_group['lr'] = param_group['lr']*0.3
    for input, label in pretrain_loaders['train']:
        steps += 1
        optimizer.zero_grad()
        model.zero_grad()
        input = input.to(DEVICE)
        label = label.to(DEVICE)
        output = model.forward(input)
        loss = criterion(output, label)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if steps%200 == 0:
            model.eval()
            with torch.no_grad():
                val_loss = 0
                val_accuracy = 0
                for input, label in pretrain_loaders['validation']:
                    input = input.to(DEVICE)
                    label = label.to(DEVICE)
                    output = model.forward(input)
                    val_loss += criterion(output, label)
                    val_accuracy += accuracy(output, label)
                val_loss = val_loss/len(pretrain_loaders['validation'])
                val_accuracy = val_accuracy/len(pretrain_loaders['validation'])
                if val_loss < best_loss:
                    best_loss = val_loss
                    torch.save(model.state_dict(), 'best_loss.pth')
                if val_accuracy > best_accuracy:
                    best_accuracy = val_accuracy
                    torch.save(model.state_dict(), 'best_accuracy.pth')
                print( 'train loss: ', running_loss/100, 'validation loss: ', val_loss, 'validation accuracy: ', val_accuracy)
                running_loss = 0
            model.train()
# Out:
# epoch:  0
# train loss:  17.216785731315614 validation loss:  tensor(7.0931, device='cuda:0') validation accuracy:  tensor(0.1576, device='cuda:0')
# train loss:  13.554371218681336 validation loss:  tensor(6.3420, device='cuda:0') validation accuracy:  tensor(0.1679, device='cuda:0')
# train loss:  12.265603737831116 validation loss:  tensor(6.0071, device='cuda:0') validation accuracy:  tensor(0.1695, device='cuda:0')
# train loss:  11.783624725341797 validation loss:  tensor(5.7330, device='cuda:0') validation accuracy:  tensor(0.1745, device='cuda:0')
# train loss:  11.393830738067628 validation loss:  tensor(5.4959, device='cuda:0') validation accuracy:  tensor(0.1780, device='cuda:0')
# train loss:  10.819482572078705 validation loss:  tensor(5.2677, device='cuda:0') validation accuracy:  tensor(0.1845, device='cuda:0')
# train loss:  10.282570133209228 validation loss:  tensor(5.0314, device='cuda:0') validation accuracy:  tensor(0.1924, device='cuda:0')
# train loss:  9.870126349925995 validation loss:  tensor(4.7436, device='cuda:0') validation accuracy:  tensor(0.2043, device='cuda:0')
# train loss:  9.206053318977355 validation loss:  tensor(4.4222, device='cuda:0') validation accuracy:  tensor(0.2201, device='cuda:0')
# train loss:  8.592421705722808 validation loss:  tensor(4.0934, device='cuda:0') validation accuracy:  tensor(0.2407, device='cuda:0')
# train loss:  8.015241873264312 validation loss:  tensor(3.7606, device='cuda:0') validation accuracy:  tensor(0.2601, device='cuda:0')
# train loss:  7.399712274074554 validation loss:  tensor(3.4919, device='cuda:0') validation accuracy:  tensor(0.2795, device='cuda:0')
# train loss:  6.617253895998001 validation loss:  tensor(3.2391, device='cuda:0') validation accuracy:  tensor(0.2989, device='cuda:0')
# train loss:  6.266439265012741 validation loss:  tensor(3.0255, device='cuda:0') validation accuracy:  tensor(0.3128, device='cuda:0')
# train loss:  5.869872688055039 validation loss:  tensor(2.8276, device='cuda:0') validation accuracy:  tensor(0.3272, device='cuda:0')
# train loss:  5.592644044160843 validation loss:  tensor(2.6568, device='cuda:0') validation accuracy:  tensor(0.3389, device='cuda:0')
# train loss:  5.061833742260933 validation loss:  tensor(2.5156, device='cuda:0') validation accuracy:  tensor(0.3503, device='cuda:0')
# train loss:  4.730766217708588 validation loss:  tensor(2.3580, device='cuda:0') validation accuracy:  tensor(0.3636, device='cuda:0')
# train loss:  4.42495159983635 validation loss:  tensor(2.2325, device='cuda:0') validation accuracy:  tensor(0.3728, device='cuda:0')
# train loss:  4.252741262316704 validation loss:  tensor(2.1109, device='cuda:0') validation accuracy:  tensor(0.3812, device='cuda:0')
# train loss:  4.06001628100872 validation loss:  tensor(2.0352, device='cuda:0') validation accuracy:  tensor(0.3863, device='cuda:0')
# train loss:  3.8555370539426805 validation loss:  tensor(1.9322, device='cuda:0') validation accuracy:  tensor(0.3941, device='cuda:0')
# train loss:  3.663363889455795 validation loss:  tensor(1.8792, device='cuda:0') validation accuracy:  tensor(0.3987, device='cuda:0')
# train loss:  3.5023459672927855 validation loss:  tensor(1.7922, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  3.435422897338867 validation loss:  tensor(1.7144, device='cuda:0') validation accuracy:  tensor(0.4090, device='cuda:0')
# train loss:  3.2638516640663147 validation loss:  tensor(1.6681, device='cuda:0') validation accuracy:  tensor(0.4097, device='cuda:0')
# train loss:  3.296951325237751 validation loss:  tensor(1.6164, device='cuda:0') validation accuracy:  tensor(0.4149, device='cuda:0')
# train loss:  3.0070943889021873 validation loss:  tensor(1.5570, device='cuda:0') validation accuracy:  tensor(0.4201, device='cuda:0')
# train loss:  3.0819577568769456 validation loss:  tensor(1.5223, device='cuda:0') validation accuracy:  tensor(0.4236, device='cuda:0')
# train loss:  2.9499466308951376 validation loss:  tensor(1.5041, device='cuda:0') validation accuracy:  tensor(0.4225, device='cuda:0')
# train loss:  2.771226153969765 validation loss:  tensor(1.4492, device='cuda:0') validation accuracy:  tensor(0.4271, device='cuda:0')
# train loss:  2.801983571946621 validation loss:  tensor(1.4189, device='cuda:0') validation accuracy:  tensor(0.4279, device='cuda:0')
# train loss:  2.579215928018093 validation loss:  tensor(1.3759, device='cuda:0') validation accuracy:  tensor(0.4311, device='cuda:0')
# train loss:  2.691616585403681 validation loss:  tensor(1.3552, device='cuda:0') validation accuracy:  tensor(0.4308, device='cuda:0')
# train loss:  2.6700617726147176 validation loss:  tensor(1.3268, device='cuda:0') validation accuracy:  tensor(0.4339, device='cuda:0')
# train loss:  2.54126680791378 validation loss:  tensor(1.3255, device='cuda:0') validation accuracy:  tensor(0.4357, device='cuda:0')
# train loss:  2.437103838250041 validation loss:  tensor(1.2656, device='cuda:0') validation accuracy:  tensor(0.4380, device='cuda:0')
# train loss:  2.4777573826909065 validation loss:  tensor(1.2512, device='cuda:0') validation accuracy:  tensor(0.4394, device='cuda:0')
# train loss:  2.3304187524318696 validation loss:  tensor(1.2194, device='cuda:0') validation accuracy:  tensor(0.4429, device='cuda:0')
# train loss:  2.2733351397514343 validation loss:  tensor(1.2096, device='cuda:0') validation accuracy:  tensor(0.4429, device='cuda:0')
# train loss:  2.140684926249087 validation loss:  tensor(1.1731, device='cuda:0') validation accuracy:  tensor(0.4435, device='cuda:0')
# train loss:  2.2901668314635755 validation loss:  tensor(1.1579, device='cuda:0') validation accuracy:  tensor(0.4425, device='cuda:0')
# train loss:  2.0910539074242114 validation loss:  tensor(1.1364, device='cuda:0') validation accuracy:  tensor(0.4460, device='cuda:0')
# train loss:  2.0714084251224993 validation loss:  tensor(1.1257, device='cuda:0') validation accuracy:  tensor(0.4472, device='cuda:0')
# train loss:  2.0995253400504588 validation loss:  tensor(1.1098, device='cuda:0') validation accuracy:  tensor(0.4477, device='cuda:0')
# train loss:  2.0435556469112637 validation loss:  tensor(1.1047, device='cuda:0') validation accuracy:  tensor(0.4483, device='cuda:0')
# train loss:  2.112597728073597 validation loss:  tensor(1.0844, device='cuda:0') validation accuracy:  tensor(0.4509, device='cuda:0')
# train loss:  1.9936569714546204 validation loss:  tensor(1.0776, device='cuda:0') validation accuracy:  tensor(0.4528, device='cuda:0')
# train loss:  1.9136284521967173 validation loss:  tensor(1.0643, device='cuda:0') validation accuracy:  tensor(0.4528, device='cuda:0')
# train loss:  1.8987174858152867 validation loss:  tensor(1.0441, device='cuda:0') validation accuracy:  tensor(0.4544, device='cuda:0')
# epoch:  1
# train loss:  1.4314147510007025 validation loss:  tensor(1.1057, device='cuda:0') validation accuracy:  tensor(0.4522, device='cuda:0')
# train loss:  1.3691470663994552 validation loss:  tensor(1.1693, device='cuda:0') validation accuracy:  tensor(0.4562, device='cuda:0')
# train loss:  1.315566435754299 validation loss:  tensor(1.1825, device='cuda:0') validation accuracy:  tensor(0.4584, device='cuda:0')
# train loss:  1.2605989318713546 validation loss:  tensor(1.1606, device='cuda:0') validation accuracy:  tensor(0.4601, device='cuda:0')
# train loss:  1.2489624031260609 validation loss:  tensor(1.1539, device='cuda:0') validation accuracy:  tensor(0.4615, device='cuda:0')
# train loss:  1.1745445451326668 validation loss:  tensor(1.1345, device='cuda:0') validation accuracy:  tensor(0.4630, device='cuda:0')
# train loss:  1.1665514375455677 validation loss:  tensor(1.1215, device='cuda:0') validation accuracy:  tensor(0.4653, device='cuda:0')
# train loss:  1.1867164481803776 validation loss:  tensor(1.0950, device='cuda:0') validation accuracy:  tensor(0.4674, device='cuda:0')
# train loss:  1.1792164297774435 validation loss:  tensor(1.0851, device='cuda:0') validation accuracy:  tensor(0.4680, device='cuda:0')
# train loss:  1.1953161858022212 validation loss:  tensor(1.1002, device='cuda:0') validation accuracy:  tensor(0.4676, device='cuda:0')
# train loss:  1.1047782846540213 validation loss:  tensor(1.1322, device='cuda:0') validation accuracy:  tensor(0.4689, device='cuda:0')
# train loss:  1.0909920980036258 validation loss:  tensor(1.0906, device='cuda:0') validation accuracy:  tensor(0.4700, device='cuda:0')
# train loss:  1.0321648531034588 validation loss:  tensor(1.1102, device='cuda:0') validation accuracy:  tensor(0.4697, device='cuda:0')
# train loss:  0.9669016816280782 validation loss:  tensor(1.0895, device='cuda:0') validation accuracy:  tensor(0.4701, device='cuda:0')
# train loss:  0.9911758233234287 validation loss:  tensor(1.0744, device='cuda:0') validation accuracy:  tensor(0.4702, device='cuda:0')
# train loss:  1.0421480188891292 validation loss:  tensor(1.0735, device='cuda:0') validation accuracy:  tensor(0.4704, device='cuda:0')
# train loss:  0.9067883691051974 validation loss:  tensor(1.0843, device='cuda:0') validation accuracy:  tensor(0.4712, device='cuda:0')
# train loss:  0.9320676491595805 validation loss:  tensor(1.0333, device='cuda:0') validation accuracy:  tensor(0.4708, device='cuda:0')
# train loss:  0.8561342570930719 validation loss:  tensor(1.0659, device='cuda:0') validation accuracy:  tensor(0.4703, device='cuda:0')
# train loss:  0.9088606305178837 validation loss:  tensor(1.0388, device='cuda:0') validation accuracy:  tensor(0.4707, device='cuda:0')
# train loss:  0.834217614531517 validation loss:  tensor(1.0500, device='cuda:0') validation accuracy:  tensor(0.4695, device='cuda:0')
# train loss:  0.8566306821466424 validation loss:  tensor(1.0454, device='cuda:0') validation accuracy:  tensor(0.4706, device='cuda:0')
# train loss:  0.7852483062073589 validation loss:  tensor(1.0487, device='cuda:0') validation accuracy:  tensor(0.4699, device='cuda:0')
# train loss:  0.7709358204528689 validation loss:  tensor(1.0456, device='cuda:0') validation accuracy:  tensor(0.4701, device='cuda:0')
# train loss:  0.7778552546421997 validation loss:  tensor(1.0579, device='cuda:0') validation accuracy:  tensor(0.4696, device='cuda:0')
# train loss:  0.7642980930954217 validation loss:  tensor(1.0551, device='cuda:0') validation accuracy:  tensor(0.4692, device='cuda:0')
# train loss:  0.7862377677462064 validation loss:  tensor(1.0366, device='cuda:0') validation accuracy:  tensor(0.4700, device='cuda:0')
# train loss:  0.6800571210496128 validation loss:  tensor(1.0509, device='cuda:0') validation accuracy:  tensor(0.4714, device='cuda:0')
# train loss:  0.7253764632716775 validation loss:  tensor(1.0642, device='cuda:0') validation accuracy:  tensor(0.4695, device='cuda:0')
# train loss:  0.6912025715736673 validation loss:  tensor(1.0444, device='cuda:0') validation accuracy:  tensor(0.4705, device='cuda:0')
# train loss:  0.6425459443079308 validation loss:  tensor(1.0566, device='cuda:0') validation accuracy:  tensor(0.4713, device='cuda:0')
# train loss:  0.6518616574117914 validation loss:  tensor(1.0936, device='cuda:0') validation accuracy:  tensor(0.4696, device='cuda:0')
# train loss:  0.5783252896694466 validation loss:  tensor(1.1223, device='cuda:0') validation accuracy:  tensor(0.4687, device='cuda:0')
# train loss:  0.6080356591334567 validation loss:  tensor(1.0800, device='cuda:0') validation accuracy:  tensor(0.4687, device='cuda:0')
# train loss:  0.6200045222681365 validation loss:  tensor(1.0354, device='cuda:0') validation accuracy:  tensor(0.4697, device='cuda:0')
# train loss:  0.6092659917171113 validation loss:  tensor(1.0062, device='cuda:0') validation accuracy:  tensor(0.4689, device='cuda:0')
# train loss:  0.5539182357303798 validation loss:  tensor(0.9987, device='cuda:0') validation accuracy:  tensor(0.4695, device='cuda:0')
# train loss:  0.57207290395163 validation loss:  tensor(0.9999, device='cuda:0') validation accuracy:  tensor(0.4680, device='cuda:0')
# train loss:  0.5350181011832319 validation loss:  tensor(0.9892, device='cuda:0') validation accuracy:  tensor(0.4693, device='cuda:0')
# train loss:  0.4994206414092332 validation loss:  tensor(1.0290, device='cuda:0') validation accuracy:  tensor(0.4678, device='cuda:0')
# train loss:  0.439865603188955 validation loss:  tensor(1.0601, device='cuda:0') validation accuracy:  tensor(0.4683, device='cuda:0')
# train loss:  0.49135046345647426 validation loss:  tensor(1.0595, device='cuda:0') validation accuracy:  tensor(0.4684, device='cuda:0')
# train loss:  0.473558084461838 validation loss:  tensor(1.0456, device='cuda:0') validation accuracy:  tensor(0.4687, device='cuda:0')
# train loss:  0.4699176290584728 validation loss:  tensor(1.0127, device='cuda:0') validation accuracy:  tensor(0.4694, device='cuda:0')
# train loss:  0.5051827192219207 validation loss:  tensor(0.9872, device='cuda:0') validation accuracy:  tensor(0.4701, device='cuda:0')
# train loss:  0.5039797736238688 validation loss:  tensor(0.9722, device='cuda:0') validation accuracy:  tensor(0.4689, device='cuda:0')
# train loss:  0.558195934034884 validation loss:  tensor(0.9471, device='cuda:0') validation accuracy:  tensor(0.4699, device='cuda:0')
# train loss:  0.4890861639752984 validation loss:  tensor(0.9371, device='cuda:0') validation accuracy:  tensor(0.4698, device='cuda:0')
# train loss:  0.4601395052927546 validation loss:  tensor(0.9429, device='cuda:0') validation accuracy:  tensor(0.4689, device='cuda:0')
# train loss:  0.48257340375101193 validation loss:  tensor(0.9247, device='cuda:0') validation accuracy:  tensor(0.4696, device='cuda:0')
# epoch:  2
# train loss:  0.7649659715872258 validation loss:  tensor(0.9601, device='cuda:0') validation accuracy:  tensor(0.4657, device='cuda:0')
# train loss:  0.7558103452110663 validation loss:  tensor(1.0432, device='cuda:0') validation accuracy:  tensor(0.4654, device='cuda:0')
# train loss:  0.7230860540596769 validation loss:  tensor(1.0674, device='cuda:0') validation accuracy:  tensor(0.4655, device='cuda:0')
# train loss:  0.6702855404955335 validation loss:  tensor(1.0505, device='cuda:0') validation accuracy:  tensor(0.4670, device='cuda:0')
# train loss:  0.6851728270004969 validation loss:  tensor(1.0515, device='cuda:0') validation accuracy:  tensor(0.4678, device='cuda:0')
# train loss:  0.6019524385337718 validation loss:  tensor(0.9990, device='cuda:0') validation accuracy:  tensor(0.4696, device='cuda:0')
# train loss:  0.5952169850154314 validation loss:  tensor(0.9882, device='cuda:0') validation accuracy:  tensor(0.4696, device='cuda:0')
# train loss:  0.5894494209205732 validation loss:  tensor(0.9828, device='cuda:0') validation accuracy:  tensor(0.4707, device='cuda:0')
# train loss:  0.5492725063720718 validation loss:  tensor(0.9813, device='cuda:0') validation accuracy:  tensor(0.4719, device='cuda:0')
# train loss:  0.5691982304491102 validation loss:  tensor(0.9913, device='cuda:0') validation accuracy:  tensor(0.4731, device='cuda:0')
# train loss:  0.4971005230641458 validation loss:  tensor(1.0039, device='cuda:0') validation accuracy:  tensor(0.4729, device='cuda:0')
# train loss:  0.4881850361381657 validation loss:  tensor(0.9743, device='cuda:0') validation accuracy:  tensor(0.4735, device='cuda:0')
# train loss:  0.4625669511186425 validation loss:  tensor(0.9906, device='cuda:0') validation accuracy:  tensor(0.4740, device='cuda:0')
# train loss:  0.4018788059259532 validation loss:  tensor(0.9799, device='cuda:0') validation accuracy:  tensor(0.4749, device='cuda:0')
# train loss:  0.4392050869483501 validation loss:  tensor(0.9484, device='cuda:0') validation accuracy:  tensor(0.4751, device='cuda:0')
# train loss:  0.48248296209028924 validation loss:  tensor(0.9484, device='cuda:0') validation accuracy:  tensor(0.4751, device='cuda:0')
# train loss:  0.37493305109499486 validation loss:  tensor(0.9551, device='cuda:0') validation accuracy:  tensor(0.4751, device='cuda:0')
# train loss:  0.3969801367074251 validation loss:  tensor(0.9274, device='cuda:0') validation accuracy:  tensor(0.4747, device='cuda:0')
# train loss:  0.355302764987573 validation loss:  tensor(0.9513, device='cuda:0') validation accuracy:  tensor(0.4754, device='cuda:0')
# train loss:  0.38006668453366727 validation loss:  tensor(0.9400, device='cuda:0') validation accuracy:  tensor(0.4753, device='cuda:0')
# train loss:  0.3210132344358135 validation loss:  tensor(0.9331, device='cuda:0') validation accuracy:  tensor(0.4749, device='cuda:0')
# train loss:  0.33462694007204846 validation loss:  tensor(0.9383, device='cuda:0') validation accuracy:  tensor(0.4756, device='cuda:0')
# train loss:  0.2866042729647597 validation loss:  tensor(0.9474, device='cuda:0') validation accuracy:  tensor(0.4754, device='cuda:0')
# train loss:  0.2656527651892975 validation loss:  tensor(0.9425, device='cuda:0') validation accuracy:  tensor(0.4747, device='cuda:0')
# train loss:  0.2756338816328207 validation loss:  tensor(0.9576, device='cuda:0') validation accuracy:  tensor(0.4745, device='cuda:0')
# train loss:  0.25310170601354914 validation loss:  tensor(0.9527, device='cuda:0') validation accuracy:  tensor(0.4750, device='cuda:0')
# train loss:  0.2662039467995055 validation loss:  tensor(0.9523, device='cuda:0') validation accuracy:  tensor(0.4752, device='cuda:0')
# train loss:  0.20452338413102553 validation loss:  tensor(0.9508, device='cuda:0') validation accuracy:  tensor(0.4758, device='cuda:0')
# train loss:  0.22244741897622589 validation loss:  tensor(0.9652, device='cuda:0') validation accuracy:  tensor(0.4747, device='cuda:0')
# train loss:  0.20434102619998157 validation loss:  tensor(0.9545, device='cuda:0') validation accuracy:  tensor(0.4748, device='cuda:0')
# train loss:  0.17415517097193514 validation loss:  tensor(0.9670, device='cuda:0') validation accuracy:  tensor(0.4746, device='cuda:0')
# train loss:  0.17724861967697506 validation loss:  tensor(0.9740, device='cuda:0') validation accuracy:  tensor(0.4749, device='cuda:0')
# train loss:  0.14276076359208673 validation loss:  tensor(1.0021, device='cuda:0') validation accuracy:  tensor(0.4746, device='cuda:0')
# train loss:  0.14745310854137642 validation loss:  tensor(0.9812, device='cuda:0') validation accuracy:  tensor(0.4747, device='cuda:0')
# train loss:  0.13399884041769838 validation loss:  tensor(0.9526, device='cuda:0') validation accuracy:  tensor(0.4760, device='cuda:0')
# train loss:  0.13967160929489184 validation loss:  tensor(0.9337, device='cuda:0') validation accuracy:  tensor(0.4755, device='cuda:0')
# train loss:  0.11843989791406784 validation loss:  tensor(0.9289, device='cuda:0') validation accuracy:  tensor(0.4760, device='cuda:0')
# train loss:  0.12441798137442675 validation loss:  tensor(0.9295, device='cuda:0') validation accuracy:  tensor(0.4755, device='cuda:0')
# train loss:  0.11670751055178698 validation loss:  tensor(0.9253, device='cuda:0') validation accuracy:  tensor(0.4750, device='cuda:0')
# train loss:  0.11419290885562078 validation loss:  tensor(0.9401, device='cuda:0') validation accuracy:  tensor(0.4740, device='cuda:0')
# train loss:  0.10494610163455946 validation loss:  tensor(0.9488, device='cuda:0') validation accuracy:  tensor(0.4738, device='cuda:0')
# train loss:  0.11680662090759142 validation loss:  tensor(0.9509, device='cuda:0') validation accuracy:  tensor(0.4737, device='cuda:0')
# train loss:  0.10200083744333824 validation loss:  tensor(0.9511, device='cuda:0') validation accuracy:  tensor(0.4744, device='cuda:0')
# train loss:  0.09329352558532264 validation loss:  tensor(0.9456, device='cuda:0') validation accuracy:  tensor(0.4746, device='cuda:0')
# train loss:  0.10213867679194663 validation loss:  tensor(0.9304, device='cuda:0') validation accuracy:  tensor(0.4751, device='cuda:0')
# train loss:  0.09591061658720719 validation loss:  tensor(0.9256, device='cuda:0') validation accuracy:  tensor(0.4749, device='cuda:0')
# train loss:  0.10947587634553202 validation loss:  tensor(0.9209, device='cuda:0') validation accuracy:  tensor(0.4746, device='cuda:0')
# train loss:  0.09589741299976595 validation loss:  tensor(0.9097, device='cuda:0') validation accuracy:  tensor(0.4746, device='cuda:0')
# train loss:  0.09175022707291645 validation loss:  tensor(0.9149, device='cuda:0') validation accuracy:  tensor(0.4744, device='cuda:0')
# train loss:  0.0991184805217199 validation loss:  tensor(0.9102, device='cuda:0') validation accuracy:  tensor(0.4746, device='cuda:0')

# %%
elmo = model.elmo
for param in elmo.parameters():
    param.requires_grad = False
elmo.weight1.requires_grad = True
elmo.weight2.requires_grad = True
elmo.lambda1.requires_grad = True

sem = NLI(elmo, embedding_dim=EMBEDDING_DIM, num_classes=3)

# %%
def accuracy(output, label):
    output = output.argmax(dim=1)
#     print(output)
    if (output == label).float().mean() == 1.0:
        print(output,label)

    return (output == label).float().mean()

sem.to(DEVICE)
criterion = nn.NLLLoss()
sem.train()

# define the optimizer
optimizer = torch.optim.SGD(sem.parameters(), lr=0.0009)
best_loss = 1000000
best_accuracy = 0
steps = 0
EPOCHS= 10
running_loss = 0
for e in range(EPOCHS):
    print('epoch: ', e)
    if e%1 == 0 and e != 0:
        for param_group in optimizer.param_groups:
            param_group['lr'] = param_group['lr']*0.5
    for input, label in nli_loaders['train']:
        steps += 1
        optimizer.zero_grad()
#         print(sem.linear.weight==w)
        input1= input[0]
        input2=input[1]
        input1 = input1.to(DEVICE)
        input2 = input2.to(DEVICE)
        label = label.to(DEVICE)
        output = sem.forward((input1,input2))
#         print(accuracy(output, label))
        loss = criterion(output, label)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        if steps%200 == 0:
            sem.eval()
            with torch.no_grad():
                val_loss = 0
                val_accuracy = 0
                for input, label in nli_loaders['validation']:
                    input1= input[0]
                    input2=input[1]
                    input1 = input1.to(DEVICE)
                    input2 = input2.to(DEVICE)
                    label = label.to(DEVICE)
                    output = sem.forward((input1,input2))
                    
                    val_loss += criterion(output, label)
                    val_accuracy+= accuracy(output , label)
        
                val_loss = val_loss/len(nli_loaders['validation'])
                val_accuracy = val_accuracy/len(nli_loaders['validation'])
                if val_loss < best_loss:
                    best_loss = val_loss
                    torch.save(sem.state_dict(), 'bl.pth')
                if val_accuracy > best_accuracy:
                    best_accuracy = val_accuracy
                    torch.save(sem.state_dict(), 'ba.pth')
                print( 'train loss: ', running_loss/100, 'validation loss: ', val_loss, 'validation accuracy: ', val_accuracy)
                running_loss = 0
            sem.train()
# Out:
# epoch:  0
# train loss:  2.1392819505929945 validation loss:  tensor(1.0756, device='cuda:0') validation accuracy:  tensor(0.3937, device='cuda:0')
# train loss:  2.130216800570488 validation loss:  tensor(1.0747, device='cuda:0') validation accuracy:  tensor(0.3987, device='cuda:0')
# train loss:  2.131500831246376 validation loss:  tensor(1.0746, device='cuda:0') validation accuracy:  tensor(0.3975, device='cuda:0')
# train loss:  2.1172248941659926 validation loss:  tensor(1.0740, device='cuda:0') validation accuracy:  tensor(0.3987, device='cuda:0')
# train loss:  2.122547444105148 validation loss:  tensor(1.0739, device='cuda:0') validation accuracy:  tensor(0.3975, device='cuda:0')
# train loss:  2.138900411128998 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.13520156621933 validation loss:  tensor(1.0745, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.1480415350198747 validation loss:  tensor(1.0739, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.1326562637090682 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.1554526114463806 validation loss:  tensor(1.0741, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.135863857269287 validation loss:  tensor(1.0739, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.105084915161133 validation loss:  tensor(1.0741, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.117302958369255 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.1596192145347595 validation loss:  tensor(1.0737, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.149457681775093 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.1376875960826873 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.141489053964615 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4000, device='cuda:0')
# train loss:  2.1404005479812622 validation loss:  tensor(1.0738, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.1194551116228104 validation loss:  tensor(1.0737, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.147883220911026 validation loss:  tensor(1.0736, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.134405959248543 validation loss:  tensor(1.0740, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.126998825073242 validation loss:  tensor(1.0735, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.1291388803720475 validation loss:  tensor(1.0732, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.146466921567917 validation loss:  tensor(1.0731, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.140121138095856 validation loss:  tensor(1.0727, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# epoch:  1
# train loss:  2.12535635471344 validation loss:  tensor(1.0726, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.135258136987686 validation loss:  tensor(1.0725, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.134804892539978 validation loss:  tensor(1.0726, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.1186656510829924 validation loss:  tensor(1.0724, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1258480286598207 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.1289846181869505 validation loss:  tensor(1.0725, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.1344072580337525 validation loss:  tensor(1.0727, device='cuda:0') validation accuracy:  tensor(0.4000, device='cuda:0')
# train loss:  2.163079101443291 validation loss:  tensor(1.0727, device='cuda:0') validation accuracy:  tensor(0.4013, device='cuda:0')
# train loss:  2.1442265188694 validation loss:  tensor(1.0729, device='cuda:0') validation accuracy:  tensor(0.4000, device='cuda:0')
# train loss:  2.146039269566536 validation loss:  tensor(1.0731, device='cuda:0') validation accuracy:  tensor(0.3987, device='cuda:0')
# train loss:  2.1386370068788527 validation loss:  tensor(1.0730, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.1100270700454713 validation loss:  tensor(1.0729, device='cuda:0') validation accuracy:  tensor(0.4000, device='cuda:0')
# train loss:  2.115644292831421 validation loss:  tensor(1.0729, device='cuda:0') validation accuracy:  tensor(0.3975, device='cuda:0')
# train loss:  2.148784218430519 validation loss:  tensor(1.0726, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.142341282367706 validation loss:  tensor(1.0727, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.141069244146347 validation loss:  tensor(1.0727, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.1511562234163284 validation loss:  tensor(1.0725, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.1396571773290636 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4038, device='cuda:0')
# train loss:  2.118206318616867 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.1457936358451843 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.1392209100723267 validation loss:  tensor(1.0725, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.120628613233566 validation loss:  tensor(1.0724, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1422595673799516 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.1403712147474288 validation loss:  tensor(1.0724, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.139678272604942 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# epoch:  2
# train loss:  2.115397174358368 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.1334182488918305 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.1256597697734834 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1211842280626296 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1249740678071976 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.128729202747345 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.1343743097782135 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.144358111023903 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4075, device='cuda:0')
# train loss:  2.113988097310066 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1566077214479447 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.133617807030678 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.097614674568176 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.111806744337082 validation loss:  tensor(1.0723, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.159759660959244 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1501448261737823 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1285059106349946 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1368180793523788 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.141334702372551 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.121091287732124 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1422977024316787 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4162, device='cuda:0')
# train loss:  2.1313831996917725 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4150, device='cuda:0')
# train loss:  2.1084196299314497 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.1350711297988894 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1366026389598844 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1212701094150543 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# epoch:  3
# train loss:  2.1265691220760345 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1225238674879074 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1278090220689774 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1331739270687105 validation loss:  tensor(1.0719, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1245418095588686 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.136702682375908 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.1203722953796387 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4150, device='cuda:0')
# train loss:  2.1440813928842544 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4175, device='cuda:0')
# train loss:  2.1258347696065902 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.142730010151863 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1268885314464567 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.098131466507912 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.114729034304619 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.147126285433769 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.14148080766201 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.1437537974119185 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.146370224356651 validation loss:  tensor(1.0720, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.132793728709221 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1242037189006804 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1504682332277296 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.140986542105675 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.114154335260391 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.135722897052765 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.147166138291359 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1347741836309435 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# epoch:  4
# train loss:  2.127638800740242 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.125692591667175 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.124678969979286 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.105853053331375 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1151762968301773 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1246335524320603 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1389162594079973 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.160021907687187 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.124628530740738 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1352966183424 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4087, device='cuda:0')
# train loss:  2.137523192167282 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1003965133428575 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4050, device='cuda:0')
# train loss:  2.117157526016235 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4062, device='cuda:0')
# train loss:  2.1610523110628126 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.140585379600525 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.129844411611557 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1356423038244245 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1365805703401564 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.118394919037819 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1322409987449644 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.133633056282997 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.112209431529045 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.13384042263031 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1483133381605146 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1409189134836195 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# epoch:  5
# train loss:  2.1208694344758987 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1201720952987673 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.122821677327156 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.118338497877121 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1190681111812593 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1329198801517486 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1288995724916457 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.147443681359291 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1239179784059523 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.1427714401483535 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.136357741355896 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.109738529920578 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.1110015815496443 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.146287299990654 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1455586522817613 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1414089995622634 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.138503167629242 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1310158455371857 validation loss:  tensor(1.0722, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1262348848581314 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1488119667768477 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4137, device='cuda:0')
# train loss:  2.131879075169563 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.120385701060295 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.14893923997879 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1382146084308626 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.129569680094719 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# epoch:  6
# train loss:  2.1258607828617095 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1221441328525543 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.11946587562561 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1270042240619658 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.116960911154747 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1337777733802796 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.127838716506958 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1481217980384826 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1257998895645143 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.150715833902359 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1239316207170487 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1034252279996872 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1195157879590987 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.140679787993431 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.144891636967659 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1326785743236543 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.129145001769066 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1281433564424517 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1118383276462556 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1291815608739855 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.131067925095558 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.11782878100872 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4125, device='cuda:0')
# train loss:  2.1397823786735533 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1373713678121566 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1335677325725557 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# epoch:  7
# train loss:  2.1201236099004745 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1265787172317503 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.117710633277893 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1304035133123396 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.129021396636963 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1345785105228425 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.127749271988869 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.14857818543911 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.128148874640465 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.139067751765251 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1183761125802993 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1019925618171693 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1172681540250777 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.147622208595276 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1423259204626084 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.149719468951225 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1367783308029176 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1344224792718887 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1131610864400865 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.144011737704277 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.140708764791489 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.123992980718613 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.144004861116409 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.146261280179024 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1301811820268632 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# epoch:  8
# train loss:  2.134494007229805 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1271682184934617 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.118879123330116 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1233742368221282 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.118483158946037 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.120041760802269 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.120275799036026 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4100, device='cuda:0')
# train loss:  2.1435876524448396 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.117823653817177 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1425059497356416 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.138147555589676 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.102513806819916 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.122442681193352 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1483378171920777 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.155647273659706 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1409640115499498 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1419733643531798 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.14596438229084 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1232635807991027 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1471430289745332 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.150155520439148 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1217285603284837 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.144322057366371 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.134598945975304 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1244288843870165 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# epoch:  9
# train loss:  2.126620519161224 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1190860772132876 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1176554453372955 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1179467421770095 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1234586101770403 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1296798729896547 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1374037700891493 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1616038501262667 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.124821694493294 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1434914577007294 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.133843097090721 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.103864768743515 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.115814244747162 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.149332671165466 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1373613375425338 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1366899728775026 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1304751980304717 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.129323402047157 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.119270758032799 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.143542290329933 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1344824719429014 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1113332897424697 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1358412981033323 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.1425670796632765 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')
# train loss:  2.131577083468437 validation loss:  tensor(1.0721, device='cuda:0') validation accuracy:  tensor(0.4112, device='cuda:0')

# %%
print(elmo.weight1, elmo.weight2)
# Out:
# Parameter containing:
# tensor([-1.8041], device='cuda:0', requires_grad=True) Parameter containing:
# tensor([-2.8250], device='cuda:0', requires_grad=True)
